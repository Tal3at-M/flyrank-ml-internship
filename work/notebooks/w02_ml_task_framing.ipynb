# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Tal3at-M/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
#Ranking & Prioritization (via Supervised Binary Classification / Scoring).
#We frame this as learning a calibrated decay probability to rank declining pages, ensuring that top-K recommendations maximize the recovery of decaying traffic.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
#Target: Binary decline label (`trend_direction == 'down'`).
#Source: It is derived from empirical search performance metrics comparing consecutive observation windows (impressions and click changes).

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
#Metric: Precision@50.
#A score > 0.70 is considered good because content teams can only refresh a limited batch of URLs per sprint, so high precision at the top of the queue is essential to avoid wasted editorial effort.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/Tal3at-M/flyrank-ml-internship/main/data/raw/content_refresh_anonymized.csv"
df = pd.read_csv(url)

print(f"Total Rows: {len(df):,}")
print("Unit of analysis: 1 row = 1 unique content URL / page")
df[["impressions_90d", "avg_position", "ctr", "content_age_days", "trend_direction"]].head(3)
# Out:
# Total Rows: 30,000
# Unit of analysis: 1 row = 1 unique content URL / page
#    impressions_90d  avg_position   ctr  content_age_days trend_direction
# 0             3803          10.6  0.76               187            down
# 1            15320          20.3  0.05               445            down
# 2            12581          36.5  0.09               141            down

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
#Fixed heuristic rules rely on hard thresholds (e.g., stale AND impressions > 500) which miss pages experiencing subtle multi-factor decay (e.g., small rank drop with sharp CTR decline). A machine learning model learns non-linear interactions across age, volume, and positioning, producing continuous risk scores instead of fragile binary filters.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
